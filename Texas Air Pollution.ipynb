# %% [markdown]
# # Analysis of School Attendance Rate by Student Group Over the Years",
# **Name:** Suryansh Saroch
# **Date:** October 20, 2023
#
#
# # Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'texas_2016_pollution.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num             Address  State  \
# 0       21762          48          113        69  1415 Hinton Street  Texas
# 1       21763          48          113        69  1415 Hinton Street  Texas
# 2       21764          48          113        69  1415 Hinton Street  Texas
# 3       21765          48          113        69  1415 Hinton Street  Texas
# 4       21766          48          113        69  1415 Hinton Street  Texas
#
#    County    City  Date Local          NO2 Units  ...          SO2 Units  \
# 0  Dallas  Dallas  2016-01-01  Parts per billion  ...  Parts per billion
# 1  Dallas  Dallas  2016-01-01  Parts per billion  ...  Parts per billion
# 2  Dallas  Dallas  2016-01-01  Parts per billion  ...  Parts per billion
# 3  Dallas  Dallas  2016-01-01  Parts per billion  ...  Parts per billion
# 4  Dallas  Dallas  2016-01-02  Parts per billion  ...  Parts per billion
#
#    SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units  \
# 0 -0.070833                0.0                11     0.0  Parts per million
# 1 -0.070833                0.0                11     0.0  Parts per million
# 2 -0.062500                0.0                11     NaN  Parts per million
# 3 -0.062500                0.0                11     NaN  Parts per million
# 4 -0.013043                0.1                13     0.0  Parts per million
#
#     CO Mean  CO 1st Max Value  CO 1st Max Hour CO AQI
# 0  0.203792             0.397               22    NaN
# 1  0.210526             0.300               22    3.0
# 2  0.203792             0.397               22    NaN
# 3  0.210526             0.300               22    3.0
# 4  0.242833             0.435               19    NaN
#
# [5 rows x 29 columns]

# %%
# Calculate the overall mean for each gas
overall_no2_mean = df['NO2 Mean'].mean()
overall_o3_mean = df['O3 Mean'].mean()
overall_so2_mean = df['SO2 Mean'].mean()
overall_co_mean = df['CO Mean'].mean()

# Prepare data for the plot
gases = ['NO2', 'O3', 'SO2', 'CO']
means = [overall_no2_mean, overall_o3_mean, overall_so2_mean, overall_co_mean]

# Plotting the bar chartS
plt.figure(figsize=(8, 6))
plt.bar(gases, means, color=['blue', 'green', 'red', 'orange'])

# Adding labels and title
plt.xlabel('Gases')
plt.ylabel('Mean Concentration')
plt.title('Mean Concentration of Gases Across States')

# Show the plot
plt.show()

# %%
# Group by city and calculate the mean NO2 pollution
city_no2 = df.groupby('City')['NO2 Mean'].mean().reset_index()

# Plotting the NO2 pollution for different cities in Texas
plt.figure(figsize=(10, 6))
plt.bar(city_no2['City'], city_no2['NO2 Mean'], color='purple')

# Rotate city names for better readability
plt.xticks(rotation=90)

# Adding labels and title
plt.xlabel('Cities in Texas')
plt.ylabel('Mean NO2 Concentration')
plt.title('Mean NO2 Pollution in Different Cities in Texas')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Extract the year and month from the 'Date Local' column
df['YearMonth'] = df['Date Local'].dt.to_period('M')

# Group by YearMonth and calculate the mean of NO2 for each month
monthly_no2 = df.groupby('YearMonth')['NO2 Mean'].mean()

# Plotting the monthly NO2 Mean
plt.figure(figsize=(10,6))
plt.plot(monthly_no2.index.astype(str), monthly_no2.values, label='NO2 Mean', color='blue')

# Adding labels and title
plt.xlabel('Month')
plt.ylabel('NO2 Mean (ppb)')
plt.title('Monthly NO2 Levels Over Time')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
